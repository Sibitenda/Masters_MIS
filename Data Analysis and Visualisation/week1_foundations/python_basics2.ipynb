# %% [markdown]
# <a href="https://colab.research.google.com/github/Sibitenda/Masters_MIS/blob/main/Data%20Analysis%20and%20Visualisation/week1_foundations/python_basics2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import requests

# %%
# df=pd.read_csv("https://github.com/Sibitenda/Masters_MIS/blob/main/Data%20Analysis%20and%20Visualisation/Data/Salaries.csv")
df = pd.read_csv("https://raw.githubusercontent.com/Sibitenda/Masters_MIS/main/Data%20Analysis%20and%20Visualisation/Data/Salaries.csv", on_bad_lines='skip')
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
import requests
import pandas as pd

url = "https://github.com/Sibitenda/Masters_MIS/blob/main/Data%20Analysis%20and%20Visualisation/Data/Salaries.csv"
raw_url = url.replace("github.com", "raw.githubusercontent.com").replace("/blob/", "/")

df = pd.read_csv(raw_url)
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#Check a particular column type
df['salary'].dtype
# Out:
# dtype('int64')

# %%
#Check types for all the columns
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %% [markdown]
# ##Hands-on Exercise

# %% [markdown]
# 1. Try to read the first 10, 20, 50 records;
#
# 2. Can you guess how to view the last few records;
#
# 3. Find how many records this data frame has;
#
# 4. How many elements are there?
#
# 5. What are the column names?
#
# 6. What types of columns we have in this data frame?
#
# 7. Give the summary for the numeric columns in the dataset;
#
# 8. Calculate standard deviation for all numeric columns;
#
# 9. What are the mean values of the first 50 records in the dataset?   Hint: use head() method to subset the first 50 records and then calculate the mean;
#
# 10. Calculate the basic statistics for the salary column;
#
# 11. Find how many values in the salary column (use count method);
#
# 12. Calculate the average salary;

# %%
#Group data using rank
df_rank = df.groupby(['rank'])

# %%
#Calculate mean value for each numeric column per each group
# df_rank.mean()
df_rank.mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
#Calculate mean salary for each professor rank:
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
#Calculate mean salary for each professor rank:
df.groupby(['rank'], sort=False)[['salary']].mean()
# Out:
#                   salary
# rank
# Prof       123624.804348
# AssocProf   91786.230769
# AsstProf    81362.789474

# %%
#Calculate mean salary for each professor rank:
df_sub = df[ df['salary'] > 120000 ]
df_sub
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
#Select only those rows that contain female professors:
df_f = df[ df['sex'] == 'Female' ]
df_f
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
#Select column salary:
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
#Select column salary:
df[['rank','salary']]
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %%
#Select rows by their position:
df[10:20]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500

# %%
#Select rows by their labels:
df_sub.loc[10:20,['rank','sex','salary']]
# Out:
#     rank   sex  salary
# 10  Prof  Male  128250
# 11  Prof  Male  134778
# 13  Prof  Male  162200
# 14  Prof  Male  153750
# 15  Prof  Male  150480
# 19  Prof  Male  150500

# %%
#Select rows by their labels:
df_sub.iloc[10:20,[0, 3, 4, 5]]
# Out:
#     rank  service     sex  salary
# 26  Prof       19    Male  148750
# 27  Prof       43    Male  155865
# 29  Prof       20    Male  123683
# 31  Prof       21    Male  155750
# 35  Prof       23    Male  126933
# 36  Prof       45    Male  146856
# 39  Prof       18  Female  129000
# 40  Prof       36  Female  137000
# 44  Prof       19  Female  151768
# 45  Prof       25  Female  140096

# %%
df.iloc[0]  # First row of a data frame
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
i = 0
df.iloc[i]  #(i+1)th row
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
# for i in range(len(df)):
#     print(df.iloc[i])  # This will now work correctly

# %%
df.iloc[-1] # Last row
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[:, 0]  # First column
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.iloc[:, -1] # Last column
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df.iloc[0:7]       #First 7 rows
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
df.iloc[:, 0:2]    #First 2 columns
# Out:
#          rank discipline
# 0        Prof          B
# 1        Prof          A
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# ..        ...        ...
# 73       Prof          B
# 74  AssocProf          B
# 75       Prof          B
# 76       Prof          A
# 77       Prof          A
#
# [78 rows x 2 columns]

# %%
df.iloc[1:3, 0:2]  #Second through third rows and first 2 columns
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A

# %%
df.iloc[[0,5], [1,3]]  #1st and 6th rows and 2nd and 4th columns
# Out:
#   discipline  service
# 0          B       49
# 5          A       20

# %%
# Create a new data frame from the original sorted by the column Salary
df_sorted = df.sort_values( by ='service')
df_sorted.head()
# Out:
#         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 17  AsstProf          B    4        0    Male   92000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 55  AsstProf          A    2        0  Female   72500

# %%
df_sorted = df.sort_values( by =['service', 'salary'], ascending = [True, False])
df_sorted.head(10)
# Out:
#         rank discipline  phd  service     sex  salary
# 52      Prof          A   12        0  Female  105000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 55  AsstProf          A    2        0  Female   72500
# 57  AsstProf          A    3        1  Female   72500
# 28  AsstProf          B    7        2    Male   91300
# 42  AsstProf          B    4        2  Female   80225
# 68  AsstProf          A    4        2  Female   77500

# %%
# Read a dataset with missing values
url= "https://github.com/Sibitenda/Masters_MIS/blob/main/Data%20Analysis%20and%20Visualisation/Data/flights.csv"
raw_url = url.replace("github.com", "raw.githubusercontent.com").replace("/blob/", "/")

flights = pd.read_csv(raw_url)

flights
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 160749  2013      9   30    2105.0       -1.0    2329.0      -25.0      UA
# 160750  2013      9   30    2121.0       21.0    2349.0      -25.0      DL
# 160751  2013      9   30    2140.0        0.0      10.0      -30.0      AA
# 160752  2013      9   30    2149.0       -7.0    2245.0      -23.0      UA
# 160753  2013      9   30    2233.0       80.0     112.0       42.0      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
# Select the rows that have at least one missing value
flights[flights.isnull().any(axis=1)].head()
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330  2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403  2013      1    1       NaN        NaN       NaN        NaN      AA
# 404  2013      1    1       NaN        NaN       NaN        NaN      AA
# 855  2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858  2013      1    2       NaN        NaN       NaN        NaN      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 330  N31412    1228    EWR  SAN       NaN      2425  18.0     7.0
# 403  N3EHAA     791    LGA  DFW       NaN      1389   NaN     NaN
# 404  N3EVAA    1925    LGA  MIA       NaN      1096   NaN     NaN
# 855  N12221    1299    EWR  RSW       NaN      1068  21.0    45.0
# 858     NaN     133    JFK  LAX       NaN      2475   NaN     NaN

# %%
flights[['dep_delay','arr_delay']].agg(['min','mean','max'])
# Out:
#         dep_delay    arr_delay
# min    -33.000000   -75.000000
# mean     9.463773     2.094537
# max   1014.000000  1007.000000

# %%
flights
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 160749  2013      9   30    2105.0       -1.0    2329.0      -25.0      UA
# 160750  2013      9   30    2121.0       21.0    2349.0      -25.0      DL
# 160751  2013      9   30    2140.0        0.0      10.0      -30.0      AA
# 160752  2013      9   30    2149.0       -7.0    2245.0      -23.0      UA
# 160753  2013      9   30    2233.0       80.0     112.0       42.0      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...
